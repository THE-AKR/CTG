# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv("1001.hea",delimiter=',')

# %%
d1
# Out:
#                                        1001 2 4 19200
# 0       1001.dat 16 100(0)/bpm 12 0 15050 20101 0 FHR
# 1                1001.dat 16 100/nd 12 0 700 378 0 UC
# 2        #----- Additional parameters for record 1001
# 3                                #-- Outcome measures
# 4                                  #pH           7.14
# 5                                  #BDecf        8.14
# 6                                   #pCO2         7.7
# 7                                 #BE           -10.5
# 8                                     #Apgar1       6
# 9                                     #Apgar5       8
# 10  #-- !NotReadyYet! Neonatology outcome measures...
# 11                                    #NICU days    0
# 12                                    #Seizures     0
# 13                                    #HIE          0
# 14                                    #Intubation   0
# 15                                    #Main diag.   0
# ...

# %%
d1_d=pd.read_csv('1001.dat',header=None)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 d1_d=pd.read_csv('1001.dat',header=None)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
d1_d=np.fromfile("1001.dat")

# %%
d1_f= pd.DataFrame(data=d1_d)

# %%
d1_f
# Out:
#                   0
# 0     1.141727e-292
# 1     1.479189e-294
# 2     1.141704e-292
# 3     4.263271e-286
# 4     4.962709e-287
# ...             ...
# 9595   0.000000e+00
# 9596   0.000000e+00
# 9597   0.000000e+00
# 9598   0.000000e+00
# 9599   0.000000e+00
#
# [9600 rows x 1 columns]

# %%
d2=pd.read_csv("1002.hea")

# %%
d2
# Out:
#                                        1002 2 4 19200
# 0        1002.dat 16 100(0)/bpm 12 0 14625 6289 0 FHR
# 1             1002.dat 16 100/nd 12 0 2600 -6136 0 UC
# 2        #----- Additional parameters for record 1002
# 3                                #-- Outcome measures
# 4                                     #pH           7
# 5                                  #BDecf        7.92
# 6                                    #pCO2         12
# 7                                   #BE           -12
# 8                                     #Apgar1       8
# 9                                     #Apgar5       8
# 10  #-- !NotReadyYet! Neonatology outcome measures...
# 11                                    #NICU days    0
# 12                                    #Seizures     0
# 13                                    #HIE          0
# 14                                    #Intubation   0
# 15                                    #Main diag.   0
# ...

# %%
d1
# Out:
#                                        1001 2 4 19200
# 0       1001.dat 16 100(0)/bpm 12 0 15050 20101 0 FHR
# 1                1001.dat 16 100/nd 12 0 700 378 0 UC
# 2        #----- Additional parameters for record 1001
# 3                                #-- Outcome measures
# 4                                  #pH           7.14
# 5                                  #BDecf        8.14
# 6                                   #pCO2         7.7
# 7                                 #BE           -10.5
# 8                                     #Apgar1       6
# 9                                     #Apgar5       8
# 10  #-- !NotReadyYet! Neonatology outcome measures...
# 11                                    #NICU days    0
# 12                                    #Seizures     0
# 13                                    #HIE          0
# 14                                    #Intubation   0
# 15                                    #Main diag.   0
# ...

# %%
x=d1["1001 2 4 19200"]

# %%
x.str.split(" ")
# Out:
# 0     [1001.dat, 16, 100(0)/bpm, 12, 0, 15050, 20101...
# 1        [1001.dat, 16, 100/nd, 12, 0, 700, 378, 0, UC]
# 2     [#-----, Additional, parameters, for, record, ...
# 3                              [#--, Outcome, measures]
# 4                       [#pH, , , , , , , , , , , 7.14]
# 5                          [#BDecf, , , , , , , , 8.14]
# 6                          [#pCO2, , , , , , , , , 7.7]
# 7                      [#BE, , , , , , , , , , , -10.5]
# 8                              [#Apgar1, , , , , , , 6]
# 9                              [#Apgar5, , , , , , , 8]
# 10    [#--, !NotReadyYet!, Neonatology, outcome, mea...
# 11                               [#NICU, days, , , , 0]
# 12                               [#Seizures, , , , , 0]
# 13                          [#HIE, , , , , , , , , , 0]
# 14                                 [#Intubation, , , 0]
# 15                                [#Main, diag., , , 0]
# 16                                 [#Other, diag., , 0]
# ...

# %%
d3= pd.read_csv("1346.hea")

# %%
d3
# Out:
#                                        1346 2 4 15600
# 0      1346.dat 16 100(0)/bpm 12 0 16425 -25193 0 FHR
# 1            1346.dat 16 100/nd 12 0 1150 -30954 0 UC
# 2        #----- Additional parameters for record 1346
# 3                                #-- Outcome measures
# 4                                  #pH           7.31
# 5                                  #BDecf        4.27
# 6                                   #pCO2         5.6
# 7                                  #BE           -5.4
# 8                                    #Apgar1       10
# 9                                    #Apgar5       10
# 10  #-- !NotReadyYet! Neonatology outcome measures...
# 11                                    #NICU days    0
# 12                                    #Seizures     0
# 13                                    #HIE          0
# 14                                    #Intubation   0
# 15                                    #Main diag.   0
# ...

# %%
d4=pd.read_csv("1436.hea")

# %%
d4
# Out:
#                                        1436 2 4 20477
# 0          1436.dat 16 100(0)/bpm 12 0 0 -29312 0 FHR
# 1               1436.dat 16 100/nd 12 0 0 -21820 0 UC
# 2        #----- Additional parameters for record 1436
# 3                                #-- Outcome measures
# 4                                  #pH           7.38
# 5                                   #BDecf        2.3
# 6                                     #pCO2         5
# 7                                    #BE           -3
# 8                                     #Apgar1       9
# 9                                     #Apgar5       9
# 10  #-- !NotReadyYet! Neonatology outcome measures...
# 11                                    #NICU days    0
# 12                                    #Seizures     0
# 13                                    #HIE          0
# 14                                    #Intubation   0
# 15                                    #Main diag.   0
# ...

# %%
d4.rename(columns={"1436 2 4 20477":"data"},inplace=True)

# %%
d4.data.str.split(" ",expand=True)
# Out:
#                0              1               2        3         4   \
# 0        1436.dat             16      100(0)/bpm       12         0
# 1        1436.dat             16          100/nd       12         0
# 2          #-----     Additional      parameters      for    record
# 3             #--        Outcome        measures     None      None
# 4             #pH
# 5          #BDecf
# 6           #pCO2
# 7             #BE
# 8         #Apgar1
# 9         #Apgar5
# 10            #--  !NotReadyYet!     Neonatology  outcome  measures
# 11          #NICU           days
# 12      #Seizures
# 13           #HIE
# 14    #Intubation                                       0      None
# 15          #Main          diag.                                  0
# 16         #Other          diag.                        0      None
# 17            #--  Fetus/Neonate     descriptors     None      None
# 18         #Gest.          weeks                       41      None
# ...

# %%
#delivery type : 1 opeartive , 2 cs
fetal and uc readings 
(high priority)unstructured data (2046 file to convert)
undefined some param
unclear aim or class
